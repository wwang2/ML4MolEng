# %% [markdown]
# #  <center> Problem Set 6 <center>
# <center> Spring 2021 <center>
# <center> 3.100/3.322, 10.402/10.602, 20.301/20.401 <center>
# <center> Due:10 pm ET on Thursday, May 19, 2021 <center>

# %%
Register for the competition and download the data: 

https://www.kaggle.com/c/ml4moleng-predicting-solvation-free-energies

# %%
# !wget https://raw.githubusercontent.com/wwang2/ML4MolEng/master/psets/ps6/data/bio/ImmuneSignatures160.csv
# !wget https://raw.githubusercontent.com/wwang2/ML4MolEng/master/psets/ps6/data/bio/Xtrain.csv
# !wget https://raw.githubusercontent.com/wwang2/ML4MolEng/master/psets/ps6/data/bio/ytrain.csv
# !wget https://raw.githubusercontent.com/wwang2/ML4MolEng/master/psets/ps6/data/bio/Xtest.csv
# Out:
# --2021-05-05 23:53:27--  https://raw.githubusercontent.com/wwang2/ML4MolEng/master/psets/ps6/data/bio/ImmuneSignatures160.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19203382 (18M) [text/plain]
# Saving to: ‘ImmuneSignatures160.csv’
#
# ImmuneSignatures160 100%[===================>]  18.31M  63.2MB/s    in 0.3s
#
# 2021-05-05 23:53:28 (63.2 MB/s) - ‘ImmuneSignatures160.csv’ saved [19203382/19203382]
#
# --2021-05-05 23:53:28--  https://raw.githubusercontent.com/wwang2/ML4MolEng/master/psets/ps6/data/bio/Xtrain.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1416971 (1.4M) [text/plain]
# Saving to: ‘Xtrain.csv’
#
# Xtrain.csv          100%[===================>]   1.35M  --.-KB/s    in 0.06s
#
# 2021-05-05 23:53:28 (22.6 MB/s) - ‘Xtrain.csv’ saved [1416971/1416971]
#
# --2021-05-05 23:53:28--  https://raw.githubusercontent.com/wwang2/ML4MolEng/master/psets/ps6/data/bio/ytrain.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36671 (36K) [text/plain]
# Saving to: ‘ytrain.csv’
#
# ytrain.csv          100%[===================>]  35.81K  --.-KB/s    in 0.002s
#
# 2021-05-05 23:53:28 (18.6 MB/s) - ‘ytrain.csv’ saved [36671/36671]
#
# --2021-05-05 23:53:28--  https://raw.githubusercontent.com/wwang2/ML4MolEng/master/psets/ps6/data/bio/Xtest.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 698484 (682K) [text/plain]
# Saving to: ‘Xtest.csv’
#
# Xtest.csv           100%[===================>] 682.11K  --.-KB/s    in 0.06s
#
# 2021-05-05 23:53:29 (12.1 MB/s) - ‘Xtest.csv’ saved [698484/698484]

# %% [markdown]
# Register for the competition and download the data:
#
# https://www.kaggle.com/c/ml4moleng-predicting-cancer/

# %% [markdown]
# ## Part 1 Characterizing Intra-Tumoral Immune States

# %% [markdown]
# ### Part 1.1  Visualization of Immune Modules

# %%
import numpy as np 
import pandas as pd 

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
# import file - immune signatures
genesig = pd.read_csv("data/ImmuneSignatures160.csv", index_col="Unnamed: 0")

# diverging colormap for visualizing standardized scores
cmap = sns.diverging_palette(220, 20, as_cmap=True)

# %%
# Immune Signature Cluster Modeling
corr = genesig.corr(method = 'pearson')
cmap = sns.diverging_palette(220, 20, as_cmap=True)
sns.clustermap(corr, cmap=cmap)

# %% [markdown]
# How many clusters can you observe? tere is no right answer, you can just provide a visual guess.

# %% [markdown]
# ### Part 1.2  Visualization of Immune Modules

# %%
# Immune Signature Cluster Modeling
corr = genesig.corr(method = 'pearson')
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state=42)
kmeans.fit(corr)

# Get silhoutte score
silhouette_score(corr, km.labels_, metric='euclidean')

# %%
# Generate Elbow plot 

silhouette_scores = []
for i in range(2,10):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state=42)
    kmeans.fit(corr)
    silhouette_scores.append(silhouette_score(corr, km.labels_, metric='euclidean'))

# %% [markdown]
# Show your plot for the mean silhouette score, and find K that corresponds to the maxium silhouette score value

# %% [markdown]
# # Part 2 Baseline Machine Learning method

# %% [markdown]
# ### 2.1 Train a Logistic Regressor

# %% [markdown]
# ### 2.2 Train a Random Forest classifier

# %% [markdown]
# # Part 3 Machine Learning Competition

# %%
# your solution to the problem, you can start a open a new notebook to put all your solutions

# train features
Xtrain = pd.read_csv("Xtrain.csv", index_col='bcr_patient_barcode')
# train labels
ytrain = pd.read_csv("Xtrain.csv", index_col='bcr_patient_barcode')
# test features 
Xtest = pd.read_csv("Xtest.csv", index_col='bcr_patient_barcode')

# %%
Xtrain
# Out:
#                      leukocyte       tcr  indel_num  immunogenic_indel_num  \
# bcr_patient_barcode
# TCGA-N8-A4PP          1.369655 -0.363639  -0.208266              -0.172899
# TCGA-34-2600         -0.889241 -0.294374  -0.183517              -0.172899
# TCGA-78-7155         -0.696687 -0.432904   1.301370               0.722221
# TCGA-G7-6792          0.062609 -0.225108  -0.208266              -0.222628
# TCGA-QR-A70V         -1.169327 -0.640701  -0.257762              -0.222628
# ...                        ...       ...        ...                    ...
# TCGA-06-2557          0.161509  1.194834  -0.208266              -0.172899
# TCGA-CV-A6JU          0.735060 -0.571435   0.088712               0.075745
# TCGA-FB-AAQ6         -0.341022 -0.502170  -0.183517              -0.272356
# TCGA-A8-A08L          0.018652  1.333365  -0.084525              -0.073441
# TCGA-BH-A1FE          1.479743 -0.640701  -0.233014              -0.272356
#
#                      neoantigen_num   snv_num  immunogenic_snv_num  \
# bcr_patient_barcode
# TCGA-N8-A4PP              -0.085580 -0.141302            -0.129469
# TCGA-34-2600              -0.166645  0.229531             0.162179
# TCGA-78-7155               0.342905  1.369600             0.545418
# TCGA-G7-6792              -0.247709 -0.221258            -0.209009
# TCGA-QR-A70V              -0.247709 -0.233665            -0.230702
# ...                             ...       ...                  ...
# TCGA-06-2557              -0.108741 -0.206094            -0.189726
# TCGA-CV-A6JU               1.014583 -0.124759            -0.129469
# TCGA-FB-AAQ6              -0.259290 -0.185416            -0.180085
# TCGA-A8-A08L              -0.166645 -0.022746            -0.016184
# TCGA-BH-A1FE              -0.259290 -0.228151            -0.223471
#
#                      B.cells.naive  B.cells.memory  Plasma.cells  ...  \
# bcr_patient_barcode                                               ...
# TCGA-N8-A4PP              0.050998       -0.549777     -0.343909  ...
# TCGA-34-2600              0.770178       -0.549777      0.412513  ...
# TCGA-78-7155              0.363095       -0.549777     -0.319799  ...
# TCGA-G7-6792             -0.729164        0.119472     -0.762129  ...
# TCGA-QR-A70V             -0.735368       -0.376346     -0.762129  ...
# ...                            ...             ...           ...  ...
# TCGA-06-2557             -0.186094       -0.549777     -0.526359  ...
# TCGA-CV-A6JU             -0.735368        3.856575     -0.402193  ...
# TCGA-FB-AAQ6             -0.735368        3.676284      0.391256  ...
# TCGA-A8-A08L              0.409819       -0.549777     -0.520260  ...
# TCGA-BH-A1FE             -0.340047       -0.549777     -0.762129  ...
#
#                      Monocytes  Macrophages.M0  Macrophages.M1  \
# bcr_patient_barcode
# TCGA-N8-A4PP          0.759229        0.493241        0.801666
# TCGA-34-2600         -0.331716       -0.722055       -0.010454
# TCGA-78-7155         -0.416092       -0.722055        0.834954
# TCGA-G7-6792          0.084073       -0.722055       -1.035023
# TCGA-QR-A70V          0.029918       -0.722055       -1.035023
# ...                        ...             ...             ...
# TCGA-06-2557          0.742568       -0.722055       -0.292185
# TCGA-CV-A6JU         -0.190858       -0.722055        0.210461
# TCGA-FB-AAQ6         -0.764200        0.532964        0.169573
# TCGA-A8-A08L          0.375173       -0.588819        1.568936
# TCGA-BH-A1FE          1.988732       -0.722055       -0.942378
#
#                      Macrophages.M2  Dendritic.cells.resting  \
# bcr_patient_barcode
# TCGA-N8-A4PP               0.127277                -0.448926
# TCGA-34-2600              -0.319344                 0.128175
# TCGA-78-7155               0.693399                -0.448926
# TCGA-G7-6792               0.422259                 2.711911
# TCGA-QR-A70V               1.893805                -0.448926
# ...                             ...                      ...
# TCGA-06-2557               2.554621                -0.448926
# TCGA-CV-A6JU               0.826419                 0.066743
# TCGA-FB-AAQ6              -0.859829                -0.448926
# TCGA-A8-A08L              -0.056878                -0.325034
# TCGA-BH-A1FE               0.290677                -0.448926
#
#                      Dendritic.cells.activated  Mast.cells.resting  \
# bcr_patient_barcode
# TCGA-N8-A4PP                          0.184844           -0.740410
# TCGA-34-2600                         -0.173511           -0.740410
# TCGA-78-7155                         -0.415868           -0.740410
# TCGA-G7-6792                          0.987802            1.484119
# TCGA-QR-A70V                          0.017025           -0.740410
# ...                                        ...                 ...
# TCGA-06-2557                         -0.415868           -0.740410
# TCGA-CV-A6JU                          1.052653           -0.663352
# TCGA-FB-AAQ6                         -0.415868            0.076080
# TCGA-A8-A08L                         -0.415868           -0.342967
# TCGA-BH-A1FE                         -0.415868           -0.740410
#
#                      Mast.cells.activated  Eosinophils  Neutrophils
# bcr_patient_barcode
# TCGA-N8-A4PP                     1.158169    -0.216233     0.124875
# TCGA-34-2600                     1.289319    -0.216233     0.285184
# TCGA-78-7155                    -0.072071    -0.216233    -0.397382
# TCGA-G7-6792                    -0.457503    -0.216233    -0.397382
# TCGA-QR-A70V                     0.822258    -0.216233    -0.397382
# ...                                   ...          ...          ...
# TCGA-06-2557                     0.001085    -0.216233     0.117723
# TCGA-CV-A6JU                    -0.449025    -0.216233    -0.332212
# TCGA-FB-AAQ6                    -0.457503    -0.216233    -0.397382
# TCGA-A8-A08L                    -0.457503    -0.216233    -0.397382
# TCGA-BH-A1FE                     0.753337     2.875290    -0.397382
#
# [2443 rows x 29 columns]

# %%
def save_submission(barcode, predict_proba, filename):
    '''
    utility function to dump submission csv files
    
    barcode (list): list of patient barcode
    predict_proba (numpy.array): 1d numpy array that contrains probabilities for 0 and 1
    filename (str): where you want to save your submission
    '''
    assert len(barcode) == len(predict_proba)
    assert len(np.shape(predict_proba)) == 2
    
    submission = pd.DataFrame( {'bcr_patient_barcode': barcode, 'Predicted': predict_proba[:, 1]})
    submission.to_csv(filename, index=None)

# %%
# You should submit probabilies for each sample instead of just 0 and 1s.

# example usage: 
save_submission(Xtest.index.tolist(), np.ones((len(Xtest), 2)), './junk.csv')
